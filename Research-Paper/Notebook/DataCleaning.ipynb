# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayush41/Everything-From-Scratch-ML/blob/main/Research-Paper/Notebook/DataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn xgboost

# %%
import pandas as pd

file_path = '/content/sample_data/EDGAR_2025_GHG_booklet_2025_fossilCO2only(info).csv'
df = pd.read_csv(file_path, encoding='latin1')

print(f"Dataset loaded successfully with {len(df)} rows and {len(df.columns)} columns.")
print("First 5 rows of the dataset:")
print(df.head())
# Out:
# Dataset loaded successfully with 26 rows and 2 columns.
# First 5 rows of the dataset:
#    GHG emissions of all world countries, 2025 Report  \
# 0                                                NaN
# 1                          How to cite this report:
# 2  Crippa M., Guizzardi D., Pagani F., Banja M., ...
# 3                                                NaN
# 4                                           Website:
#
#                                    Unnamed: 1
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4  https://edgar.jrc.ec.europa.eu/report_2025
